# %% [markdown]
#    # Projeto 2 - Ciência do Dados
# ___
#
#    ## Arthur Pansini; Enzo Fonteyne; Andre Faia.

# %% [markdown]
#    Nosso projeto é focado na industria automobilistica, na qual utilizamos das variaveis ano de fabricação, modelo, tipo de câmbio e quilometros rodados para analizar quais dessas caracteristicas estão mais presentes em carros vendidos acima dos 20 mil dolares. Buscamos trazer uma base de dados ampla e com enorme diversidade de informações acerca do tema, para que se aproxime o maximo possível da realidade!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("train.csv")
data.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# 1     Tiptronic          4x4  04-May        Left wheel   Black        8
# 2      Variator        Front  04-May  Right-hand drive   Black        2
# 3     Automatic          4x4  04-May        Left wheel   White        0
# 4     Automatic        Front  04-May        Left wheel  Silver        4

# %%
filtro = data.loc[:,["Price", "Prod. year", "Category", "Manufacturer",  "Model","Gear box type", "Mileage", 'Cylinders',
                    'Engine volume', 'Airbags']]

# %%
filtro
# Out:
#        Price  Prod. year   Category   Manufacturer    Model Gear box type  \
# 0      13328        2010       Jeep          LEXUS   RX 450     Automatic
# 1      16621        2011       Jeep      CHEVROLET  Equinox     Tiptronic
# 2       8467        2006  Hatchback          HONDA      FIT      Variator
# 3       3607        2011       Jeep           FORD   Escape     Automatic
# 4      11726        2014  Hatchback          HONDA      FIT     Automatic
# ...      ...         ...        ...            ...      ...           ...
# 19232   8467        1999      Coupe  MERCEDES-BENZ  CLK 200        Manual
# 19233  15681        2011      Sedan        HYUNDAI   Sonata     Tiptronic
# 19234  26108        2010       Jeep        HYUNDAI   Tucson     Automatic
# 19235   5331        2007       Jeep      CHEVROLET  Captiva     Automatic
# 19236    470        2012      Sedan        HYUNDAI   Sonata     Automatic
#
#          Mileage  Cylinders Engine volume  Airbags
# 0      186005 km        6.0           3.5       12
# 1      192000 km        6.0             3        8
# 2      200000 km        4.0           1.3        2
# 3      168966 km        4.0           2.5        0
# 4       91901 km        4.0           1.3        4
# ...          ...        ...           ...      ...
# 19232  300000 km        4.0     2.0 Turbo        5
# 19233  161600 km        4.0           2.4        8
# 19234  116365 km        4.0             2        4
# 19235   51258 km        4.0             2        4
# 19236  186923 km        4.0           2.4       12
#
# [19237 rows x 10 columns]

# %%
filtro.isnull().sum()
# Out:
# Price            0
# Prod. year       0
# Category         0
# Manufacturer     0
# Model            0
# Gear box type    0
# Mileage          0
# Cylinders        0
# Engine volume    0
# Airbags          0
# dtype: int64

# %%
filtro.tail(10)
# Out:
#        Price  Prod. year   Category   Manufacturer    Model Gear box type  \
# 19227  29793        2014      Sedan  MERCEDES-BENZ    E 350     Automatic
# 19228    706        2008      Sedan  MERCEDES-BENZ    E 350     Automatic
# 19229     50        2008  Hatchback         TOYOTA    Prius     Automatic
# 19230    470        2011  Hatchback         TOYOTA    Prius     Automatic
# 19231   5802        2013      Sedan  MERCEDES-BENZ    E 350     Automatic
# 19232   8467        1999      Coupe  MERCEDES-BENZ  CLK 200        Manual
# 19233  15681        2011      Sedan        HYUNDAI   Sonata     Tiptronic
# 19234  26108        2010       Jeep        HYUNDAI   Tucson     Automatic
# 19235   5331        2007       Jeep      CHEVROLET  Captiva     Automatic
# 19236    470        2012      Sedan        HYUNDAI   Sonata     Automatic
#
#          Mileage  Cylinders Engine volume  Airbags
# 19227  219030 km        6.0           3.5       12
# 19228  122874 km        6.0           3.5       12
# 19229  150000 km        4.0           1.5        6
# 19230  307325 km        4.0           1.8       12
# 19231  107800 km        6.0           3.5       12
# 19232  300000 km        4.0     2.0 Turbo        5
# 19233  161600 km        4.0           2.4        8
# 19234  116365 km        4.0             2        4
# 19235   51258 km        4.0             2        4
# 19236  186923 km        4.0           2.4       12

# %%
data1 = (filtro.loc[filtro['Price']>=20000])
data1 = (data1.loc[filtro['Price']<=500000])

# %%
data1.describe()
# Out:
#                Price   Prod. year    Cylinders      Airbags
# count    5689.000000  5689.000000  5689.000000  5689.000000
# mean    37283.067147  2013.602566     4.686237     6.609773
# std     21450.351507     3.616127     1.344163     3.954730
# min     20000.000000  1943.000000     1.000000     0.000000
# 25%     23772.000000  2012.000000     4.000000     4.000000
# 50%     30891.000000  2014.000000     4.000000     4.000000
# 75%     43576.000000  2016.000000     6.000000    11.000000
# max    308906.000000  2020.000000    16.000000    16.000000

# %%
data1.isnull().sum()
# Out:
# Price            0
# Prod. year       0
# Category         0
# Manufacturer     0
# Model            0
# Gear box type    0
# Mileage          0
# Cylinders        0
# Engine volume    0
# Airbags          0
# dtype: int64

# %%
data1['Mileage'] = data['Mileage'].map(lambda x: x.lstrip('+-').rstrip(' km'))
data1['Mileage'] = data1['Mileage'].astype('int64')

# %%
data1['Gear box type'] = data1['Gear box type'].astype('category')
data1['Gear box type'].cat.categories
# Out:
# Index(['Automatic', 'Manual', 'Tiptronic', 'Variator'], dtype='object')

# %%
data1['Gear box type'].cat.categories = [0, 1, 2, 3]
data1['Gear box type'] = data1['Gear box type'].astype('int64')

# %%
data1['Engine volume'] = data1['Engine volume'].map(lambda x: x.lstrip('+-').rstrip(' Turbo'))
data1['Engine volume'] = data1['Engine volume'].astype('float64')

# %%
data1.Category.describe()
# Out:
# count     5689
# unique      11
# top       Jeep
# freq      2629
# Name: Category, dtype: object

# %%
data1.tail(10)
# Out:
#        Price  Prod. year   Category   Manufacturer        Model  \
# 19198  28225        2015       Jeep         TOYOTA        RAV 4
# 19200  36065        2013      Sedan  MERCEDES-BENZ  CLA 250 AMG
# 19206  22075        2012  Universal         TOYOTA         Aqua
# 19207  22197        2012  Hatchback         TOYOTA         Aqua
# 19208  34811        2013       Jeep         TOYOTA        RAV 4
# 19211  50037        2016       Jeep        HYUNDAI     Santa FE
# 19216  37633        2017       Jeep         TOYOTA        RAV 4
# 19217  26017        2009      Sedan          LEXUS       ES 300
# 19227  29793        2014      Sedan  MERCEDES-BENZ        E 350
# 19234  26108        2010       Jeep        HYUNDAI       Tucson
#
#        Gear box type  Mileage  Cylinders  Engine volume  Airbags
# 19198              0   149019        4.0            2.5        0
# 19200              2    68000        4.0            2.0       12
# 19206              0    52456        4.0            1.5        4
# 19207              0    50000        4.0            1.5        4
# 19208              2   121400        4.0            2.5        6
# 19211              0   121902        4.0            2.0        4
# 19216              2    23430        4.0            2.5       12
# 19217              0   132700        4.0            3.5        4
# 19227              0   219030        6.0            3.5       12
# 19234              0   116365        4.0            2.0        4

# %%
sns.pairplot(data1, height=3)

# %%
data1.dtypes
# Out:
# Price              int64
# Prod. year         int64
# Category          object
# Manufacturer      object
# Model             object
# Gear box type      int64
# Mileage            int64
# Cylinders        float64
# Engine volume    float64
# Airbags            int64
# dtype: object
